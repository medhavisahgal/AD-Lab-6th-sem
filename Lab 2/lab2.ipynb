# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Sample dataset (This is a sample dataset, we can use a real-time .csv file dataset)
data = {
    "Area": [750, 800, 1200, 1500, 2000, 2500, 3000],
    "Rooms": [2, 3, 3, 4, 5, 6, 7],
    "Price": [150000, 180000, 250000, 300000, 400000, 500000, 600000],
}
df = pd.DataFrame(data)

# Features (Area, Rooms) and Target (Price)
X = df[["Area", "Rooms"]]
y = df["Price"]

# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

# Model evaluation
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R-squared Score:", r2)

# Visualizing regression line (scatter plot for one feature - Area)
plt.scatter(df["Area"], df["Price"], color="blue", label="Actual Data")
plt.plot(df["Area"], model.predict(df[["Area", "Rooms"]]), color="red", label="Regression Line")
plt.xlabel("Area (sq ft)")
plt.ylabel("Price (in USD)")
plt.title("Simple Linear Regression: House Prices")
plt.legend()
plt.show()
# Out:
# Mean Squared Error: 352083333.3333324
# R-squared Score: 0.9859665633303809

# %%
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Sample data
X = np.array([[1, 2], [2, 3], [3, 4], [4, 5]])
y = np.array([5, 6, 7, 8])

# Define second-order polynomial features
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# Fit the model
model = LinearRegression()
model.fit(X_poly, y)

# Predictions
y_pred = model.predict(X_poly)
print(y_pred)
# Out:
# [5. 6. 7. 8.]

# %%
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Sample data
X = np.array([[1, 2, 3], [2, 3, 4], [3, 4, 5], [4, 5, 6]])
y = np.array([7, 8, 9, 10])

# Define second-order polynomial features
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# Fit the model
model = LinearRegression()
model.fit(X_poly, y)

# Predictions
y_pred = model.predict(X_poly)
print(y_pred)
# Out:
# [ 7.  8.  9. 10.]

# %%
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Sample data
X = np.array([[1, 2], [2, 3], [3, 4], [4, 5]])
y = np.array([5, 6, 7, 8])

# Define third-order polynomial features
poly = PolynomialFeatures(degree=3)
X_poly = poly.fit_transform(X)

# Fit the model
model = LinearRegression()
model.fit(X_poly, y)

# Predictions
y_pred = model.predict(X_poly)
print(y_pred)
# Out:
# [5. 6. 7. 8.]

# %%
import numpy as np
from scipy.stats import pearsonr

# Sample data
ages = np.array([43, 21, 25, 42, 57, 59])
glucose_levels = np.array([99, 65, 79, 75, 87, 81])

# Calculate the correlation coefficient
correlation_coefficient, _ = pearsonr(ages, glucose_levels)

print(f"Correlation Coefficient: {correlation_coefficient}")
# Out:
# Correlation Coefficient: 0.5298089018901743

# %%
import math

# Data from the table
companies = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']
sales_Y = [25, 35, 29, 24, 38, 12, 18, 27, 17, 30]  # Sales in 1000s (Y)
agents_X = [8, 12, 11, 5, 14, 3, 6, 8, 4, 9]        # Number of agents in 100s (X)

# Step 1: Calculate required sums
n = len(sales_Y)
sum_X = sum(agents_X)
sum_Y = sum(sales_Y)
sum_XY = sum(x * y for x, y in zip(agents_X, sales_Y))
sum_X2 = sum(x**2 for x in agents_X)
sum_Y2 = sum(y**2 for y in sales_Y)

# Step 2: Calculate correlation coefficient (r)
numerator = (n * sum_XY) - (sum_X * sum_Y)
denominator = math.sqrt((n * sum_X2 - sum_X**2) * (n * sum_Y2 - sum_Y**2))

r = numerator / denominator

# Display results
print("Number of data points (n):", n)
print("Sum of X:", sum_X)
print("Sum of Y:", sum_Y)
print("Sum of XY:", sum_XY)
print("Sum of X^2:", sum_X2)
print("Sum of Y^2:", sum_Y2)
print("Correlation Coefficient (r):", round(r, 2))
# Out:
# Number of data points (n): 10
# Sum of X: 80
# Sum of Y: 255
# Sum of XY: 2289
# Sum of X^2: 756
# Sum of Y^2: 7097
# Correlation Coefficient (r): 0.95
